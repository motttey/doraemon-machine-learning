# %%
import json
import requests
import time
from bs4 import BeautifulSoup
import re
import pandas as pd

# %%
def fetch_abstract(index, max_length):
    url = 'https://www.tv-asahi.co.jp/doraemon/story/{0}/'.format(index)
    html_text = requests.get(url).text
    soup = BeautifulSoup(html_text, 'html.parser')

    # 整構造でない場合はテキスト全部取得する
    p_list = soup.find_all('p', class_="txt_idt") if len(soup.find_all('p', class_="txt_idt")) > 0 else soup.find('div', class_='contentsarea').find_all('p')
    abstracts_list = [ asbstract_dom.text for asbstract_dom in p_list]
    strong_list = soup.find_all('strong')
    title_list = [ strong.text for strong in strong_list]
    # title_list = soup.find('h2').text if (strong_list > 0) else soup.find('p').find('strong').text
    broadcasting_date = re.sub(r'[\[\]放送]', '', soup.find('h2').find('span').text)
    print(broadcasting_date)

    if len(title_list) == len(abstracts_list): 
        return [ {
            "index": index,
            "stories_index": i,
            "title": title,
            "broadcasting_date": broadcasting_date,
            # 50文字ある文章のみ抽出
            "abstracts_list": [abstract]
        } for i, (abstract, title) in enumerate(zip(abstracts_list, title_list))]
    else:
        return [{
            "index": index,
            "stories_index": 1,
            "title": title_list,
            "broadcasting_date": broadcasting_date,
            # 50文字ある文章のみ抽出
            "abstracts_list": [asbstract for asbstract in abstracts_list if len(asbstract) > max_length]
        }]

# %%
start = 325
end = 743
max_length = 50

stories_list = []
for i in range(start, end+1):
    s_zero = str(i).zfill(4)
    print(i)
    stories_list = stories_list + fetch_abstract(s_zero, max_length)
    time.sleep(5)
# Out:
# 325
# 2013年3月15日
# 326
# 2013年4月12日
# 327
# 2013年4月26日
# 328
# 2013年5月3日
# 329
# 2013年5月10日
# 330
# 2013年5月17日
# 331
# 2013年5月24日
# 332
# 2013年5月31日
# 333
# 2013年6月7日
# 334
# 2013年6月14日
# 335
# 2013年6月21日
# 336
# 2013年7月5日
# 337
# 2013年7月12日
# 338
# 2013年7月26日
# 339
# 2013年8月9日
# 340
# 2013年8月16日
# 341
# 2013年8月23日
# 342
# 2013年8月30日
# 343
# 2013年9月6日
# 344
# 2013年9月13日
# 345
# 2013年10月18日
# 346
# 2013年10月25日
# 347
# 2013年11月1日
# 348
# 2013年11月8日
# 349
# 2013年11月15日
# 350
# 2013年12月6日
# 351
# 2013年12月13日
# 352
# 2013年12月30日
# 353
# 2014年1月17日
# 354
# 2014年1月31日
# 355
# 2014年2月7日
# 356
# 2014年2月14日
# 357
# 2014年2月28日
# 358
# 2014年3月7日
# 359
# 2014年3月14日
# 360
# 2014年4月11日
# 361
# 2014年4月18日
# 362
# 2014年4月25日
# 363
# 2014年5月2日
# 364
# 2014年5月16日
# 365
# 2014年5月23日
# 366
# 2014年5月30日
# 367
# 2014年6月6日
# 368
# 2014年6月13日
# 369
# 2014年6月20日
# 370
# 2014年6月27日
# 371
# 2014年7月11日
# 372
# 2014年8月1日
# 373
# 2014年8月8日
# 374
# 2014年8月29日
# 375
# 2014年9月5日
# 376
# 2014年9月12日
# 377
# 2014年9月19日
# ...

# %%
stories_dict = pd.DataFrame.from_dict(stories_list)
stories_dict.head()
# Out:
#   index  stories_index                            title broadcasting_date  \
# 0  0325              1  [「映画ドラえもん のび太の新魔界大冒険～７人の魔法使い～」]        2013年3月15日
# 1  0326              1        [「ばくはつコショウ」, 「何が何でもお花見を」]        2013年4月12日
# 2  0327              1   [「やりクリしてハワイ旅行」, 「しずかちゃんのはごろも」]        2013年4月26日
# 3  0328              1          [「ひるねは天国で」, 「どくさいスイッチ」]         2013年5月3日
# 4  0329              1        [「インスタントママ」, 「狙われたジャイアン」]        2013年5月10日
#
#                                       abstracts_list
# 0  [　何をやってもうまくいかないのび太は、「魔法（まほう）が使えたら便利で楽しくなるにちがいな...
# 1  [　ある朝、ねぼうしたのび太に泣きつかれたドラえもんは、『ばくはつコショウ』を取り出す。この...
# 2  [　スネ夫からハワイ旅行をじまんされたのび太は、自分もハワイに行きたいとママにたのもうとする...
# 3  [　のび太とドラえもんが部屋で昼寝をしていると、突然大きな音が聞こえてくる。となりの家が改築...
# 4  [　そうじにせんたく、町内会の会合と毎日大忙しのママが、「体がもうひとつほしい」とため息をつ...

# %%
stories_dict.sort_values("index", ascending=False).head()
# Out:
#     index  stories_index           title broadcasting_date  \
# 685  0743              1  「雪だるまが町にやってきた」        2023年1月28日
# 684  0743              0  「鬼のパンツはいいパンツ？」        2023年1月28日
# 683  0742              1   「のび泥棒をタイホせよ！」        2023年1月21日
# 682  0742              0     「ありがたみわかり機」        2023年1月21日
# 681  0741              1  「夜空に輝くピザ・ギョーザ」        2023年1月14日
#
#                                         abstracts_list
# 685  [冬のスポーツが楽しめる“ウインタースポーツランド”にやって来たのび太たち。スキーもスケート...
# 684  [５回連続で０点を取ってしまったのび太。来週のテストも０点だったら、ママが鬼（おに）になって...
# 683  [小さな子どもたちがおにごっこをして遊んでいるのを見かけたのび太は、自分たちもやろうとみんな...
# 682  [おなかがいっぱいだからと食事を残すのび太に、ご飯が食べられるありがたみについて話すママ。と...
# 681  [星がきれいにかがやく夜、のび太がスネ夫の家の前を通ると、庭で星空パーティーが開かれていた。...

# %%
with open("output_stories_0122.json", 'w') as f:
    json.dump(stories_list, f)
